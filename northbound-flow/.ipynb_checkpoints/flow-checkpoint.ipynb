# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import mpl
mpl.rcParams['font.sans-serif']=['SimHei']
mpl.rcParams['axes.unicode_minus']=False

import tushare as ts
token = '876d9d597843c92c8e6aba164d160c9600d5fc00ade3ab91e00162c5'
pro = ts.pro_api(token)

def get_cal_date(star, end):
    cal_date = pro.trade_cal(exchange='', start_date=start, end_date=end)
    cal_date = cal_date[cal_date.is_open==1]
    dates = cal_date.cal_date.values
    return dates

def get_north_money(start, end):
    dates = get_cal_date(start, end)
    df = pro.moneyflow_hsgt(start_date=start, end_date=end)
    for i in range(0, len(dates)-300, 300):
        d0 = pro.moneyflow_hsgt(start_date = dates[i], end_date = dates[i+300])
        df = pd.concat([d0,df])
        df = df.drop_duplicates()
        df.index = pd.to_datetime(df.trade_date)
        df = df.sort_index()
    return df

def get_index_data(code, start, end):
    index_df = pro.index_daily(ts_code = code, start_date = start, end_date = end)
#     print(index_df)
    index_df.index = pd.to_datetime(index_df.trade_date)
    index_df = index_df.sort_index()
    return index_df

# %%
indexs = {'沪深300': '000300.sh', '中证500': '000905.SH'}
start = '20141117'
end = '20200815'
index_data = pd.DataFrame()
for name, code in indexs.items():
    index_data[name] = get_index_data(code, start, end)['close']

# %%
print(index_data['沪深300'])
# Out:
# trade_date
# 2014-11-17    2567.1010
# 2014-11-18    2541.4160
# 2014-11-19    2537.2230
# 2014-11-20    2537.0990
# 2014-11-21    2583.4550
#                 ...
# 2020-08-10    4724.8697
# 2020-08-11    4681.7837
# 2020-08-12    4647.6446
# 2020-08-13    4635.7126
# 2020-08-14    4704.6288
# Name: 沪深300, Length: 1402, dtype: float64

# %%
print(index_data.iloc[0])
# Out:
# 沪深300    2567.101
# 中证500    4958.466
# Name: 2014-11-17 00:00:00, dtype: float64

# %%
print(index_data/index_data.iloc[0])
# Out:
#                沪深300     中证500
# trade_date
# 2014-11-17  1.000000  1.000000
# 2014-11-18  0.989995  1.001852
# 2014-11-19  0.988361  1.005372
# 2014-11-20  0.988313  1.003259
# 2014-11-21  1.006371  1.014381
# ...              ...       ...
# 2020-08-10  1.840547  1.356326
# 2020-08-11  1.823763  1.331228
# 2020-08-12  1.810464  1.316617
# 2020-08-13  1.805816  1.321509
# 2020-08-14  1.832662  1.335809
#
# [1402 rows x 2 columns]

# %%
(index_data/index_data.iloc[0]).plot(figsize=(14,6))
plt.title('Return 2014~2020', size=15)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
all_ret = index_data/index_data.shift(1) - 1
north_data = get_north_money(start, end)
print(all_ret)
print(north_data)
# Out:
#                沪深300     中证500
# trade_date
# 2014-11-17       NaN       NaN
# 2014-11-18 -0.010005  0.001852
# 2014-11-19 -0.001650  0.003513
# 2014-11-20 -0.000049 -0.002101
# 2014-11-21  0.018271  0.011086
# ...              ...       ...
# 2020-08-10  0.003599  0.005444
# 2020-08-11 -0.009119 -0.018505
# 2020-08-12 -0.007292 -0.010975
# 2020-08-13 -0.002567  0.003716
# 2020-08-14  0.014866  0.010821
#
# [1402 rows x 2 columns]
#            trade_date   ggt_ss   ggt_sz       hgt      sgt  north_money  \
# trade_date
# 2014-11-17   20141117  1768.00     None  13000.00     None     13000.00
# 2014-11-18   20141118   800.00     None   4845.00     None      4845.00
# 2014-11-19   20141119   253.00     None   2612.00     None      2612.00
# 2014-11-20   20141120   196.00     None   2276.00     None      2276.00
# 2014-11-21   20141121   186.00     None   2341.00     None      2341.00
# ...               ...      ...      ...       ...      ...          ...
# 2020-08-10   20200810  -269.32  2969.41   1399.39 -1392.02         7.37
# 2020-08-11   20200811    -1.89   533.41   2124.47  1823.75      3948.22
# 2020-08-12   20200812   265.20    -1.58    948.04 -2585.78     -1637.74
# 2020-08-13   20200813  -201.87   263.64  -1022.55 -1059.62     -2082.17
# 2020-08-14   20200814   614.57  2043.66   3433.85  2995.22      6429.07
#
#             south_money
# trade_date
# 2014-11-17      1768.00
# 2014-11-18       800.00
# 2014-11-19       253.00
# 2014-11-20       196.00
# 2014-11-21       186.00
# ...                 ...
# 2020-08-10      2700.09
# 2020-08-11       531.52
# 2020-08-12       263.62
# 2020-08-13        61.77
# 2020-08-14      2658.23
#
# [1358 rows x 7 columns]

# %%
all_data = all_ret.join(north_data['north_money'], how='inner')
all_data.rename(columns{'北向资金': 'north_money'}, inplace=True)
all_data.dropna(inplace=True)
print(all_data)
# Out:
#                沪深300     中证500  north_money
# trade_date
# 2014-11-17       NaN       NaN     13000.00
# 2014-11-18 -0.010005  0.001852      4845.00
# 2014-11-19 -0.001650  0.003513      2612.00
# 2014-11-20 -0.000049 -0.002101      2276.00
# 2014-11-21  0.018271  0.011086      2341.00
# ...              ...       ...          ...
# 2020-08-10  0.003599  0.005444         7.37
# 2020-08-11 -0.009119 -0.018505      3948.22
# 2020-08-12 -0.007292 -0.010975     -1637.74
# 2020-08-13 -0.002567  0.003716     -2082.17
# 2020-08-14  0.014866  0.010821      6429.07
#
# [1358 rows x 3 columns]
